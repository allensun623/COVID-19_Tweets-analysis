# %%
# import libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# And libraries for data transformation
import datetime

#words counter
from collections import Counter
import re

# %%
df = pd.read_csv('src/Groundtruth.csv')
df
# Out:
#           id_str                      created_at         state sentiment  \
# 0   1.230000e+18  Mon Mar 02 02:31:01 +0000 2020    Washington   neutral
# 1   1.230000e+18  Mon Mar 02 02:55:14 +0000 2020      Maryland   neutral
# 2   1.230000e+18  Mon Mar 02 02:55:26 +0000 2020      New York  positive
# 3   1.230000e+18  Mon Mar 02 02:10:10 +0000 2020         Texas  positive
# 4   1.240000e+18  Mon Mar 16 01:26:36 +0000 2020         Texas  positive
# ..           ...                             ...           ...       ...
# 95  1.240000e+18  Mon Mar 16 01:47:49 +0000 2020      New York  negative
# 96  1.230000e+18  Mon Mar 02 02:11:35 +0000 2020  Pennsylvania   neutral
# 97  1.230000e+18  Mon Mar 02 02:10:47 +0000 2020         Texas   neutral
# 98  1.240000e+18  Mon Mar 16 01:05:53 +0000 2020         Texas  positive
# 99  1.240000e+18  Mon Mar 16 01:06:23 +0000 2020    California  positive
#
#                                                 Tweet Evaluator    Rating
# ...

# %% [markdown]
# # Data preprocessing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id_str      100 non-null    float64
#  1   created_at  100 non-null    object
#  2   state       96 non-null     object
#  3   sentiment   100 non-null    object
#  4   Tweet       98 non-null     object
#  5   Evaluator   100 non-null    object
#  6   Rating      75 non-null     object
# dtypes: float64(1), object(6)
# memory usage: 5.6+ KB

# %%
df_test = df[['Tweet', 'Rating']]
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tweet   98 non-null     object
#  1   Rating  75 non-null     object
# dtypes: object(2)
# memory usage: 1.7+ KB

# %%
df_test = df_test.dropna()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tweet   73 non-null     object
#  1   Rating  73 non-null     object
# dtypes: object(2)
# memory usage: 1.7+ KB

# %%
df_test['Rating_score'] = df_test['Rating'].apply(lambda x: 1 if x == 'Positive' else -1 if x == 'Negative' else 0)
df_test
# Out:
#                                                 Tweet    Rating  Rating_score
# 0                                    covid kingcounty   Neutral             0
# 1   washington state reports second coronavirus death  Negative            -1
# 2   announcing first positive case covid new york ...  Positive             1
# 3   people get coronavirus whole world wants wear ...  Negative            -1
# 4   theres drive thru covid test north austin doma...   Neutral             0
# ..                                                ...       ...           ...
# 95  coronavirus updatemeeting mayor excused restro...   Neutral             0
# 96  breaking second person died coronavirus covid ...  Negative            -1
# 97                                            florida   Neutral             0
# 98  coronavirus closing schools china month ago te...  Positive             1
# 99  norway developed socialist country called stud...  Negative            -1
#
# [73 rows x 3 columns]

# %% [markdown]
# # Model analysis

# %%
# sentiment 
# sentiment 
from textblob import TextBlob
def textblob_sen(x):
    score = TextBlob(x).sentiment[0]
    if score > 1:
        return 1
    elif score == 0:
        return 0
    else:
        return -1
        
        
from textblob import TextBlob
models = {'TextBlob': lambda x: textblob_sen(x)}

for name, model in models.items():
    df_test[name] = df_test['Tweet'].apply(lambda x: model(x))

df_test
# Out:
#                                                 Tweet    Rating  Rating_score  \
# 0                                    covid kingcounty   Neutral             0
# 1   washington state reports second coronavirus death  Negative            -1
# 2   announcing first positive case covid new york ...  Positive             1
# 3   people get coronavirus whole world wants wear ...  Negative            -1
# 4   theres drive thru covid test north austin doma...   Neutral             0
# ..                                                ...       ...           ...
# 95  coronavirus updatemeeting mayor excused restro...   Neutral             0
# 96  breaking second person died coronavirus covid ...  Negative            -1
# 97                                            florida   Neutral             0
# 98  coronavirus closing schools china month ago te...  Positive             1
# 99  norway developed socialist country called stud...  Negative            -1
#
#     TextBlob
# 0          0
# ...

# %%
from sentistrength import PySentiStr

def sentistrength_sen(x):
    score = PySentiStr().getSentiment(x)
    if score > 1:
        return 1
    elif score == 0:
        return 0
    else:
        return -1
        
        
models = {'sentistrength': lambda x: sentistrength_sen(x)}

for name, model in models.items():
    df_test[name] = df_test['Tweet'].apply(lambda x: model(x))

df_test
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-10-535537426e8c> in <module>
#      14
#      15 for name, model in models.items():
# ---> 16     df_test[name] = df_test['Tweet'].apply(lambda x: model(x))
#      17
#      18 df_test
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-10-535537426e8c> in <lambda>(x)
#      14
#      15 for name, model in models.items():
# ---> 16     df_test[name] = df_test['Tweet'].apply(lambda x: model(x))
#      17
#      18 df_test
#
# ...
